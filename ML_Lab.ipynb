# %% [markdown]
# <a href="https://colab.research.google.com/github/GopariIndhu/machine-learning/blob/main/ML_Lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import numpy as np

# %%
df=pd.read_csv(r"/content/studentdetails.csv")

# %%
df
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu     NaN  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.shape
# Out:
# (9, 4)

# %%
df.head()
# Out:
#    student  rollno branch admission
# 0   sharon    41.0     it       yes
# 1    indhu    48.0    cse        no
# 2    kavya    29.0  civil        no
# 3  srinija    32.0   mech       yes
# 4    sindu    36.0    NaN        no

# %%
df.tail()
# Out:
#     student  rollno branch admission
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu     NaN  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.describe()
# Out:
#           rollno
# count   8.000000
# mean   41.875000
# std    15.896428
# min    21.000000
# 25%    31.250000
# 50%    38.500000
# 75%    51.250000
# max    67.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   student    9 non-null      object
#  1   rollno     8 non-null      float64
#  2   branch     8 non-null      object
#  3   admission  9 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 416.0+ bytes

# %%
df.isnull().sum()
# Out:
# student      0
# rollno       1
# branch       1
# admission    0
# dtype: int64

# %%
df.rollno=df.rollno.fillna(df.rollno.median())

# %%
df.branch=df.branch.fillna(df.branch.mode())

# %%
df
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.isnull().sum()
# Out:
# student      0
# rollno       0
# branch       1
# admission    0
# dtype: int64

# %%
df.columns
# Out:
# Index(['student', 'rollno', 'branch', 'admission'], dtype='object')

# %%
df.loc[2:5]
# Out:
#     student  rollno branch admission
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes

# %%
df.loc[df.rollno>40]
# Out:
#   student  rollno branch admission
# 0  sharon    41.0     it       yes
# 1   indhu    48.0    cse        no
# 7    rama    61.0   mech        no
# 8    rani    67.0     it        no

# %%
df.loc[df.rollno<40]
# Out:
#     student  rollno branch admission
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes

# %%
df
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.shape
# Out:
# (9, 4)

# %%
df.iloc[:,:]
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.iloc[:,0:3]
# Out:
#     student  rollno branch
# 0    sharon    41.0     it
# 1     indhu    48.0    cse
# 2     kavya    29.0  civil
# 3   srinija    32.0   mech
# 4     sindu    36.0    NaN
# 5  soujnaya    21.0    cse
# 6      ramu    38.5  civil
# 7      rama    61.0   mech
# 8      rani    67.0     it

# %%
df.iloc[:,[0,2]]
# Out:
#     student branch
# 0    sharon     it
# 1     indhu    cse
# 2     kavya  civil
# 3   srinija   mech
# 4     sindu    NaN
# 5  soujnaya    cse
# 6      ramu  civil
# 7      rama   mech
# 8      rani     it

# %%
x=df.iloc[:,-1]

# %%
x=df.iloc[:,-1:]

# %%
df.iloc[:,-1:]
# Out:
#   admission
# 0       yes
# 1        no
# 2        no
# 3       yes
# 4        no
# 5       yes
# 6       yes
# 7        no
# 8        no

# %%
df.iloc[:,range(0,3)]
# Out:
#     student  rollno branch
# 0    sharon    41.0     it
# 1     indhu    48.0    cse
# 2     kavya    29.0  civil
# 3   srinija    32.0   mech
# 4     sindu    36.0    NaN
# 5  soujnaya    21.0    cse
# 6      ramu    38.5  civil
# 7      rama    61.0   mech
# 8      rani    67.0     it

# %%
df.shape
# Out:
# (9, 4)

# %%
df.columns
# Out:
# Index(['student', 'rollno', 'branch', 'admission'], dtype='object')

# %%
df['student'].value_counts()
# Out:
# student
# sharon      1
# indhu       1
# kavya       1
# srinija     1
# sindu       1
# soujnaya    1
# ramu        1
# rama        1
# rani        1
# Name: count, dtype: int64

# %%
df['branch'].value_counts()
# Out:
# branch
# it       2
# cse      2
# civil    2
# mech     2
# Name: count, dtype: int64

# %%
print(df)
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
print(df)
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.head()
# Out:
#    student  rollno branch admission
# 0   sharon    41.0     it       yes
# 1    indhu    48.0    cse        no
# 2    kavya    29.0  civil        no
# 3  srinija    32.0   mech       yes
# 4    sindu    36.0    NaN        no

# %%
import matplotlib.pyplot as plt
import plotly.express as px

fig = px.histogram(df, x = 'student')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.histogram(df, x = 'branch')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.head()
# Out:
#    student  rollno branch admission
# 0   sharon    41.0     it       yes
# 1    indhu    48.0    cse        no
# 2    kavya    29.0  civil        no
# 3  srinija    32.0   mech       yes
# 4    sindu    36.0    NaN        no

# %%
print(df)
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.rollno=df.rollno.fillna(df.rollno.median())

# %%
print(df)
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.branch=df.branch.fillna(df.branch.mode())

# %%
df
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.rollno=df.rollno.fillna(df.rollno.mean())

# %%
df
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0    NaN        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
df.isnull().sum()
# Out:
# student      0
# rollno       0
# branch       1
# admission    0
# dtype: int64

# %%
df['branch'].fillna(df.branch.mode()[0],inplace=True)

# %%
df
# Out:
#     student  rollno branch admission
# 0    sharon    41.0     it       yes
# 1     indhu    48.0    cse        no
# 2     kavya    29.0  civil        no
# 3   srinija    32.0   mech       yes
# 4     sindu    36.0  civil        no
# 5  soujnaya    21.0    cse       yes
# 6      ramu    38.5  civil       yes
# 7      rama    61.0   mech        no
# 8      rani    67.0     it        no

# %%
from sklearn.preprocessing import LabelEncoder
from collections import Counter as count
le=LabelEncoder()
print('Before label Encoding: ',count(df['branch']))
df['branch']=le.fit_transform(df['branch'])
print('After label Encoding: ',count(df['branch']))
# Out:
# Before label Encoding:  Counter({'civil': 3, 'it': 2, 'cse': 2, 'mech': 2})
# After label Encoding:  Counter({0: 3, 2: 2, 1: 2, 3: 2})

# %%
print('Before label Encoding: ',count(df['student']))
df['student']=le.fit_transform(df['student'])
print('After Replace: ',count(df['student']))
# Out:
# Before label Encoding:  Counter({'sharon': 1, 'indhu': 1, 'kavya': 1, 'srinija': 1, 'sindu': 1, 'soujnaya': 1, 'ramu': 1, 'rama': 1, 'rani': 1})
# After Replace:  Counter({5: 1, 0: 1, 1: 1, 8: 1, 6: 1, 7: 1, 3: 1, 2: 1, 4: 1})

# %%
df.shape
# Out:
# (9, 4)

# %%
df
# Out:
#    student  rollno  branch admission
# 0        5    41.0       2       yes
# 1        0    48.0       1        no
# 2        1    29.0       0        no
# 3        8    32.0       3       yes
# 4        6    36.0       0        no
# 5        7    21.0       1       yes
# 6        3    38.5       0       yes
# 7        2    61.0       3        no
# 8        4    67.0       2        no

# %%
print('Before label Encoding: ',count(df['admission']))
df['admission']=le.fit_transform(df['admission'])
print('After Replace: ',count(df['admission']))
# Out:
# Before label Encoding:  Counter({'no': 5, 'yes': 4})
# After Replace:  Counter({0: 5, 1: 4})

# %%
#from sklearn.compose import ColumnTransformer
#from sklearn.preprocessing import OneHotEncoder
#ct=ColumnTransformer([('on',OneHotEncoder(),[0])],remainder='passthrough')
#df=ct.fit_transform(df)

# %%
df.shape
# Out:
# (9, 4)

# %%
df
# Out:
#    student  rollno  branch  admission
# 0        5    41.0       2          1
# 1        0    48.0       1          0
# 2        1    29.0       0          0
# 3        8    32.0       3          1
# 4        6    36.0       0          0
# 5        7    21.0       1          1
# 6        3    38.5       0          1
# 7        2    61.0       3          0
# 8        4    67.0       2          0

# %%
#from sklearn.preprocessing import StandardScaler
#sc=StandardScaler()
#df=sc.fit_transform(df)

# %%
df
# Out:
#    student  rollno  branch  admission
# 0        5    41.0       2          1
# 1        0    48.0       1          0
# 2        1    29.0       0          0
# 3        8    32.0       3          1
# 4        6    36.0       0          0
# 5        7    21.0       1          1
# 6        3    38.5       0          1
# 7        2    61.0       3          0
# 8        4    67.0       2          0

# %%
y=df['admission']
y
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# 5    1
# 6    1
# 7    0
# 8    0
# Name: admission, dtype: int64

# %%
x=df.iloc[:, 0:-1]
x
# Out:
#    student  rollno  branch
# 0        5    41.0       2
# 1        0    48.0       1
# 2        1    29.0       0
# 3        8    32.0       3
# 4        6    36.0       0
# 5        7    21.0       1
# 6        3    38.5       0
# 7        2    61.0       3
# 8        4    67.0       2

# %%
#x=pd.DataFrame(df[:,0:6],columns=['it','cse','civil','mech','student','rollno'])
#x

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x,y ,random_state=0, test_size=0.2)

# %%
X_train
# Out:
#    student  rollno  branch
# 1        0    48.0       1
# 4        6    36.0       0
# 8        4    67.0       2
# 6        3    38.5       0
# 3        8    32.0       3
# 0        5    41.0       2
# 5        7    21.0       1

# %%
X_test
# Out:
#    student  rollno  branch
# 7        2    61.0       3
# 2        1    29.0       0

# %%
y_test
# Out:
# 7    0
# 2    0
# Name: admission, dtype: int64

# %%
y_train
# Out:
# 1    0
# 4    0
# 8    0
# 6    1
# 3    1
# 0    1
# 5    1
# Name: admission, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression
model_lr = LogisticRegression(max_iter=1000)
model_lr.fit(X_train,y_train)
y_pred_train=model_lr.predict(X_train)
y_pred_test=model_lr.predict(X_test)

# %%
print(y_pred_test)
# Out:
# [0 1]

# %%
from sklearn.metrics import accuracy_score, confusion_matrix

# %%
accuracy_train=accuracy_score(y_train,y_pred_train)
print("Accuracy of the logistic regression model on your train",accuracy_train)
# Out:
# Accuracy of the logistic regression model on your train 0.8571428571428571

# %%
accuracy_test=accuracy_score(y_test,y_pred_test)
print("Accuracy of the logistic regression model on your test dataset is: ",accuracy_test)
# Out:
# Accuracy of the logistic regression model on your test dataset is:  0.5

# %%
confusion_matrix(y_test,y_pred_test)
# Out:
# array([[1, 1],
#        [0, 0]])

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
#call the model
dt = DecisionTreeClassifier(criterion='entropy')
#fit the model
dt.fit(X_train,y_train)
#predict the model
y_pred_test  = dt.predict(X_test)
y_pred_train = dt.predict(X_train)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# Create a Linear Regression model
model_lr = LinearRegression()

# Train the model on the training data
model_lr.fit(X_train, y_train)

# Predictions on the training and test data
y_pred_train_lr = model_lr.predict(X_train)
y_pred_test_lr = model_lr.predict(X_test)

# Calculate metrics (optional)
train_mse_lr = mean_squared_error(y_train, y_pred_train_lr)
test_mse_lr = mean_squared_error(y_test, y_pred_test_lr)
train_r2_lr = r2_score(y_train, y_pred_train_lr)
test_r2_lr = r2_score(y_test, y_pred_test_lr)
